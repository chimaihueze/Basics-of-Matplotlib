# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Create Labels for a Plot
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.

# %%
# Example
# Add labels to the x- and y-axis:

ab = np.array([10, 20, 30, 40, 50, 60])
ac = np.array([15, 65, 75, 80, 85, 90])

plt.plot(ab, ac)

plt.xlabel('Age')
plt.ylabel('Average Weight')
# Out:
# Text(0, 0.5, 'Average Weight')

# %%
# Create a Title for a Plot
# With Pyplot, you can use the title() function to set a title for the plot.

# Example
# Add a plot title and labels for the x- and y-axis:

plt.plot(ab, ac)

plt.xlabel('Age')
plt.ylabel('Average Weight')
plt.title('Patient Details')
# Out:
# Text(0.5, 1.0, 'Patient Details')

# %%
# Set Font Properties for Title and Labels
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# Example
# Set font properties for the title and labels:

font1 = {'family': 'Arial', 'color': 'blue', 'size': 15}
font2 = {'family': 'Roboto', 'color': 'red', 'size': 20}

plt.title('Patient Details', fontdict = font2)
plt.xlabel('Age', fontdict = font1)
plt.ylabel('Average Weight', fontdict = font1)

plt.plot(ab, ac)

# %%
# You can use the loc parameter in title() to position the title.

# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# Example
# Position the title to the left:

plt.title('Patient Data', loc = 'left')
# Out:
# Text(0.0, 1.0, 'Patient Data')

# %%
plt.title('Patient Data', loc = 'right')
# Out:
# Text(1.0, 1.0, 'Patient Data')

# %%
plt.title('Patient Data', loc = 'center')
# Out:
# Text(0.5, 1.0, 'Patient Data')
